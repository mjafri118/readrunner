# %%
from ReadRunner import readRunner

# %%
rawText = input("Enter news article: ")
WPM = int(input("Enter WPM: "))
readRunner(rawText, WPM)
# Out:
# Enter news article: https://www.msn.com/en-us/news/us/apple-employee-was-detained-by-us-border-agents-over-his-iphone-laptop/ar-BBVFdJr
# Enter WPM: 300
# <video width="360" height="216" controls autoplay loop>
#   <source type="video/mp4" src="...
